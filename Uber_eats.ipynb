# %%
import pandas as pd
from matplotlib import pyplot
import statistics
from scipy import stats
import numpy as np
import plotly.express as px

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
import os
os.getcwd()
os.chdir(r'C:\Users\officeuser\Downloads')

# %%
Data = pd.read_excel('Uber_Eats.xlsx')

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3977 entries, 0 to 3976
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Account: Account Name      3977 non-null   object
#  1   Account: Sales Tier        3567 non-null   object
#  2   Account: Cuisine           3409 non-null   object
#  3   Account: Cuisine Category  3977 non-null   object
# dtypes: object(4)
# memory usage: 124.4+ KB

# %%
Data["Account: Cuisine Category"].value_counts()[:15].plot(kind='bar')
plt.show()

# %%
Data["Account: Account Name"].value_counts()[:15]
# Out:
# Subway                               42
# House Of Pops                         7
# Pop O'Bob - Premium Bubble Tea        5
# G. Pulla Reddy Sweets                 5
# Cafe Coffee Day                       5
# 7th Heaven                            5
# New Green Bawarchi                    4
# New Green Bawarchi Restaurant         4
# Baskin Robbins                        4
# Green Bawarchi                        4
# Makers Of Milkshakes                  4
# The New Green Bawarchi                4
# ABC - Absolutely Broasted Chicken     4
# Deccan Spices                         3
# Biryani House                         3
# Name: Account: Account Name, dtype: int64

# %%
plt.figure(figsize= (12,7))
df_target= Data["Account: Sales Tier"].value_counts()
plt.pie(df_target, labels= df_target.index, autopct= '%.1f%%', startangle= 90, explode= [0.05, 0.05,0.05], shadow = True )
plt.legend(['Tier 2', 'Tier 3','Tier 1'])
plt.title('Sales Tier for Resturants in Hyderabad', fontsize= 16)
plt.show()

# %%
Anna = Data.groupby(["Account: Sales Tier","Account: Cuisine Category"])

# %%
Anna.count()
# Out:
#                                                Account: Account Name  \
# Account: Sales Tier Account: Cuisine Category
# Tier 1              American                                       9
#                     Arabic                                        36
#                     Asian Fusion                                   5
#                     Asian: Other                                  13
#                     Bakery                                        41
# ...                                                              ...
# Tier 3              Snacks                                        84
#                     Soul Food                                      1
#                     Southern                                      21
#                     Vegetarian / Vegan                             1
#                     Vegetarian/Vegan                               3
#
#                                                Account: Cuisine
# ...
